# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os 
import zipfile
from tqdm import tqdm
from glob import glob
from shutil import copy, move

# %% [markdown]
# ## Data Preparation

# %%
zipfile_dir = '../input/dogs-vs-cats/train.zip'
train_dir = zipfile.ZipFile(zipfile_dir, 'r')
train_dir.extractall()

zipfile_dir = '../input/dogs-vs-cats/test1.zip'
test_dir = zipfile.ZipFile(zipfile_dir, 'r')
test_dir.extractall()

# %%
TRAIN_DIR = './train'
TEST_DIR = './test1'

train_set = os.listdir(TRAIN_DIR)
test_set = os.listdir(TEST_DIR)

print('#train images: %s'%len(train_set))
print('#test images: %s'%len(test_set))
print(train_set[:5])
print(test_set[:5])
# Out:
# #train images: 25000
# #test images: 12500
# ['dog.11202.jpg', 'dog.4393.jpg', 'dog.10714.jpg', 'dog.1801.jpg', 'cat.8228.jpg']
# ['6774.jpg', '10253.jpg', '1936.jpg', '5530.jpg', '9485.jpg']

# %%
dog_train_dir = './training/dog'
dog_val_dir = './validation/dog'
cat_train_dir = './training/cat'
cat_val_dir = './validation/cat'

file_dirs = [dog_train_dir, dog_val_dir, cat_train_dir, cat_val_dir]

for dir in file_dirs:
    os.makedirs(dir,exist_ok = True)

# %%
all_dogs = glob('./train/dog*jpg')
all_cats = glob('./train/cat*jpg')

print(len(all_dogs))
print(len(all_cats))
# Out:
# 12500
# 12500

# %%
from sklearn.model_selection import train_test_split

dogs_train, dogs_test = train_test_split(all_dogs, test_size=0.1, shuffle=True,random_state = 100)
cats_train, cats_test = train_test_split(all_cats, test_size=0.1, shuffle=True,random_state = 100)

# %%
for name in tqdm(dogs_train):
  copy(name , os.path.join(dog_train_dir , name.split('/')[-1]))
for name in tqdm(cats_train):
  copy(name , os.path.join(cat_train_dir , name.split('/')[-1]))
  
for name in tqdm(dogs_test):
  copy(name , os.path.join(dog_val_dir , name.split('/')[-1]))
for name in tqdm(cats_test):
  copy(name , os.path.join(cat_val_dir , name.split('/')[-1]))
# Out:
# 100%|██████████| 11250/11250 [00:02<00:00, 5293.97it/s]
# 100%|██████████| 11250/11250 [00:02<00:00, 5563.02it/s]
# 100%|██████████| 1250/1250 [00:00<00:00, 5539.76it/s]
# 100%|██████████| 1250/1250 [00:00<00:00, 5718.13it/s]

# %%
print(len(os.listdir(dog_train_dir)))
print(len(os.listdir(cat_train_dir)))
print(len(os.listdir(dog_val_dir)))
print(len(os.listdir(cat_val_dir)))
# Out:
# 11250
# 11250
# 1250
# 1250

# %% [markdown]
# ## Data Preprocessing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

TRAINING_DIR = './training'
train_datagen = ImageDataGenerator(rescale=1 / 255)
train_generator = train_datagen.flow_from_directory(
    TRAINING_DIR,
    batch_size=64,
    class_mode='binary',
    target_size=(150, 150)
)

VALIDATION_DIR = './validation'
validation_datagen = ImageDataGenerator(rescale=1/255)
validation_generator = validation_datagen.flow_from_directory(
    VALIDATION_DIR,
    batch_size = 64,
    class_mode = 'binary',
    target_size = (150, 150)
)
# Out:
# Found 22500 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %% [markdown]
# ## Model Creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPool2D, Flatten, Dropout

model = Sequential()
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal',input_shape=(150, 150, 3)))
model.add(Conv2D(64, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Conv2D(128, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(256, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(Dropout(0.4))
model.add(Conv2D(512, (3,3), strides=(1,1), padding='same', activation='relu',kernel_initializer='he_normal'))
model.add(MaxPool2D((2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 150, 150, 64)      1792
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 150, 150, 64)      36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 75, 75, 64)        0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 75, 75, 128)       73856
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 75, 75, 128)       147584
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 37, 37, 128)       0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 37, 37, 256)       295168
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 37, 37, 256)       0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 37, 37, 256)       0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 37, 37, 256)       590080
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 18, 18, 256)       0
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 18, 18, 512)       1180160
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 18, 18, 512)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 18, 18, 512)       0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 18, 18, 512)       2359808
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 9, 9, 512)         0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 9, 9, 512)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 41472)             0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1024)              42468352
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 52,351,425
# Trainable params: 52,351,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
check_point_path = './best.h5'
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath = check_point_path,
    monitor = 'val_accuracy',
    save_weights_only=False,
    save_best_only=True,
    verbose=1
)

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.0005,decay=1e-5),
             loss = 'binary_crossentropy',
             metrics = ['acc'])

# %%
print('Num Params : ',model.count_params())
model_history = model.fit(
    train_generator,
    epochs=25,
    verbose=1,
    callbacks = [model_checkpoint],
    validation_data=validation_generator
)
# Out:
# Num Params :  52351425
# Epoch 1/25
# 352/352 [==============================] - 93s 261ms/step - loss: 1.1708 - acc: 0.5070 - val_loss: 0.6927 - val_acc: 0.5476
# Epoch 2/25
# 352/352 [==============================] - 91s 259ms/step - loss: 0.6999 - acc: 0.5129 - val_loss: 0.6925 - val_acc: 0.5104
# Epoch 3/25
# 352/352 [==============================] - 91s 258ms/step - loss: 0.6947 - acc: 0.5195 - val_loss: 0.6926 - val_acc: 0.5012
# Epoch 4/25
# 352/352 [==============================] - 91s 258ms/step - loss: 0.6907 - acc: 0.5295 - val_loss: 0.6926 - val_acc: 0.5004
# Epoch 5/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6881 - acc: 0.5402 - val_loss: 0.6926 - val_acc: 0.5000
# Epoch 6/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6872 - acc: 0.5368 - val_loss: 0.6926 - val_acc: 0.5000
# Epoch 7/25
# 352/352 [==============================] - 92s 261ms/step - loss: 0.6860 - acc: 0.5478 - val_loss: 0.6925 - val_acc: 0.5000
# Epoch 8/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6831 - acc: 0.5610 - val_loss: 0.6928 - val_acc: 0.5000
# Epoch 9/25
# 352/352 [==============================] - 92s 261ms/step - loss: 0.6826 - acc: 0.5683 - val_loss: 0.6926 - val_acc: 0.5000
# Epoch 10/25
# 352/352 [==============================] - 91s 259ms/step - loss: 0.6840 - acc: 0.5553 - val_loss: 0.6928 - val_acc: 0.5000
# Epoch 11/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6800 - acc: 0.5656 - val_loss: 0.6925 - val_acc: 0.5000
# Epoch 12/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6789 - acc: 0.5758 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 13/25
# 352/352 [==============================] - 92s 261ms/step - loss: 0.6807 - acc: 0.5737 - val_loss: 0.6930 - val_acc: 0.5000
# Epoch 14/25
# 352/352 [==============================] - 91s 259ms/step - loss: 0.6772 - acc: 0.5791 - val_loss: 0.6928 - val_acc: 0.5000
# Epoch 15/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6752 - acc: 0.5814 - val_loss: 0.6926 - val_acc: 0.5000
# Epoch 16/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6721 - acc: 0.5911 - val_loss: 0.6927 - val_acc: 0.5000
# Epoch 17/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6693 - acc: 0.5904 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 18/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6668 - acc: 0.6041 - val_loss: 0.6931 - val_acc: 0.5000
# Epoch 19/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6646 - acc: 0.5996 - val_loss: 0.6929 - val_acc: 0.5000
# Epoch 20/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6656 - acc: 0.5989 - val_loss: 0.6932 - val_acc: 0.5000
# Epoch 21/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6609 - acc: 0.6082 - val_loss: 0.6933 - val_acc: 0.5004
# Epoch 22/25
# 352/352 [==============================] - 91s 257ms/step - loss: 0.6573 - acc: 0.6098 - val_loss: 0.6933 - val_acc: 0.5008
# Epoch 23/25
# 352/352 [==============================] - 92s 261ms/step - loss: 0.6526 - acc: 0.6209 - val_loss: 0.6929 - val_acc: 0.5012
# Epoch 24/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6502 - acc: 0.6176 - val_loss: 0.6933 - val_acc: 0.5012
# Epoch 25/25
# 352/352 [==============================] - 92s 260ms/step - loss: 0.6516 - acc: 0.6132 - val_loss: 0.6935 - val_acc: 0.5016

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# Plotting Loss and Accuracy

# %%
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=model_history.history['acc']
val_acc=model_history.history['val_acc']
loss=model_history.history['loss']
val_loss=model_history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r')
plt.plot(epochs, val_acc, 'b')
plt.title('Training and validation accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(["Training Accuracy","Validation Accuracy"])
plt.show()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r')
plt.plot(epochs, val_loss, 'b')
plt.title('Training and validation loss')
plt.title('Training and validation loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(["Training Loss","Validation Loss"])
plt.show()

# Desired output. Charts with training and validation metrics.

# %%
test_file = os.listdir("./test1")
test_df = pd.DataFrame({
    'filename': test_file
})
test_df
# Out:
#         filename
# 0       6774.jpg
# 1      10253.jpg
# 2       1936.jpg
# 3       5530.jpg
# 4       9485.jpg
# ...          ...
# 12495   3852.jpg
# 12496   3016.jpg
# 12497   1553.jpg
# 12498   2741.jpg
# 12499   7073.jpg
#
# [12500 rows x 1 columns]

# %%
TESTING_DIR = './test1'
test_generator = train_datagen.flow_from_dataframe(
    test_df,
    directory = TESTING_DIR,
    x_col='filename',
    y_col=None,
    batch_size=64,
    target_size=(150, 150),
    shuffle = False,
    class_mode = None
)
# Out:
# Found 12500 validated image filenames.

# %%
test_generator.reset()
y_pred = model.predict(test_generator)

# %% [markdown]
# To see the class mapping of dogs and cats, we have to see class_indices from training dataset

# %%
train_generator.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %% [markdown]
# Let's make labels

# %%
y_pred_classification = np.where(y_pred > 0.5, 1, 0)
y_pred_classification
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %% [markdown]
# Seeing some results

# %%
test_generator.reset()
test_images = test_generator[0][:9]

fig, ax = plt.subplots(3,3)
fig.set_size_inches(10,10)
for i, img in enumerate(test_images):
    ax[i//3][i%3].imshow(img)
    if y_pred_classification[i]==1:
        label = 'Dog'
    else:
        label = 'Cat'
    ax[i//3][i%3].set_title(label)

# %% [markdown]
# Visualizing first 9 filters

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3b5b2290>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3b5b7d50>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f2d3b5b71d0>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d3b5bdcd0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3b5b7e90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3a475f10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3a477d50>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f2d3b62fb10>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f28bc296a90>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3b9f2b90>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d3b666110>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3a474d50>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d3b69a590>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3ba231d0>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f2d10122a10>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d3b625f10>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3a478790>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d3b625950>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d3b6a6450>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d3b508710>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f2d1050e390>,
#  <tensorflow.python.keras.layers.pooling.MaxPooling2D at 0x7f2d3b666910>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d1013be90>,
#  <tensorflow.python.keras.layers.core.Flatten at 0x7f2d1051ec50>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f2d1050cdd0>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d3b508150>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f2d10506c10>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d10532b50>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f2d1050aa90>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f2d10506310>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f2d10532f90>]

# %%
first_conv = model.layers[0]
output_layer1 = first_conv(test_images)[4]

print(output_layer1.shape)
fig, ax = plt.subplots(3,3)
fig.set_size_inches(10,10)
for i in range(9):
  ax[i//3][i%3].imshow(output_layer1[:,:,i])
# Out:
# (150, 150, 64)

# %% [markdown]
# ## Submition

# %%
submission = pd.read_csv('../input/dogs-vs-cats/sampleSubmission.csv')
submission['label'] = y_pred_classification
submission
# Out:
#           id  label
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 12495  12496      0
# 12496  12497      0
# 12497  12498      0
# 12498  12499      0
# 12499  12500      0
#
# [12500 rows x 2 columns]

# %%
submission.to_csv('submission.csv',index='False')
